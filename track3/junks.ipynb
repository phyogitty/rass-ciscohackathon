# %%
import numpy as np
import pandas as pd

# emails = pd.read_csv('emails.csv')
# df = emails.tail(1000)
# df.to_csv(r'last_1000.csv', index = False)

# %%
bag = ['meeting', 'meet', 'available', ' pm', ' pm ', ' am', ' am ', ]
emails['message'].head()
# Out:
# 0    Message-ID: <18782981.1075855378110.JavaMail.e...
# 1    Message-ID: <15464986.1075855378456.JavaMail.e...
# 2    Message-ID: <24216240.1075855687451.JavaMail.e...
# 3    Message-ID: <13505866.1075863688222.JavaMail.e...
# 4    Message-ID: <30922949.1075863688243.JavaMail.e...
# Name: message, dtype: object

# %%
def parse_raw_message(raw_message):
    lines = raw_message.split('\n')
    email = {}
    message = ''
    keys_to_extract = ['from', 'to', 'subject']
    for line in lines:
        if ':' not in line:
            message += line.strip()
            email['body'] = message
        else:
            pairs = line.split(':')
            key = pairs[0].lower()
            val = line[len(key)+1:]
            if key in keys_to_extract:
                email[key] = val
    return email
def parse_into_emails(messages):
    emails = [parse_raw_message(message) for message in messages]
    return emails
#     return {
#         'body': map_to_list(emails, 'body'), 
#         'to': map_to_list(emails, 'to'), 
#         'from_': map_to_list(emails, 'from')
#     }

# %%
email_df = pd.DataFrame(parse_into_emails(emails.message))
email_df['body'] = email_df['body']
bodies = email_df['body']
is_useful = [0, 0, 0,0,1,]
for idx, body in zip(range(len(bodies)), bodies):
    print(idx)
    print(body)
# Out:
# 0
# mike.cowan@enron.com
# 1
# After some brief discussions with UBS in Houston, we must wait before we can make final determination of our functional currency.  We may be evaluated in Canadian dollars rather than American.  I must get some direction from UBS
# 2
# 403-974-6706-----Original Message-----Howdy!  I hope all is well.What is your fax# @ work?Brother Smith
# 3
# ...

# %%
# model = LinearSVC()
# X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)
# from sklearn.metrics import confusion_matrix
# conf_mat = confusion_matrix(y_test, y_pred)
# fig, ax = plt.subplots(figsize=(10,10))
# sns.heatmap(conf_mat, annot=True, fmt='d',
#             xticklabels=category_id_df.Useful.values, yticklabels=category_id_df.Useful.values)
# plt.ylabel('Actual')
# plt.xlabel('Predicted')
# plt.show()



# models = [
#     RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
#     LinearSVC(),
#     MultinomialNB(),
#     LogisticRegression(random_state=0),
# ]
# CV = 5
# cv_df = pd.DataFrame(index=range(CV * len(models)))
# entries = []
# for model in models:
#     model_name = model.__class__.__name__
#     accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
#     for fold_idx, accuracy in enumerate(accuracies):
#         entries.append((model_name, fold_idx, accuracy))
# cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# import seaborn as sns
# sns.boxplot(x='model_name', y='accuracy', data=cv_df)
# sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
#               size=8, jitter=True, edgecolor="gray", linewidth=2)
# plt.show()

# cv_df.groupby('model_name').accuracy.mean()
# model = LinearSVC()
# X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.2, random_state=0)
# # X_train[:20]
# print("X Test ", X_test.shape)
# print("Y Test ", y_test.shape)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)
# test_accuracy = np.mean(y_pred == y_test)
# print("Testing Accuracy: ", test_accuracy)

# y_pred_train = model.predict(X_train)
# train_accuracy = np.mean(y_pred_train == y_train)
# print("Training Accuracy: ", train_accuracy)

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
# features = tfidf.fit_transform(df.Body).toarray()
# labels = df.category_id
# features.shape

# from sklearn.feature_selection import chi2
# import numpy as np
# N = 2
# a = []
# for Useful, category_id in sorted(category_to_id.items()):
# #     print("...", category_id)
#     features_chi2 = chi2(features, labels == category_id)
  
#     indices = np.argsort(features_chi2[0])
#     feature_names = np.array(tfidf.get_feature_names())[indices]
# #     print(" ..... ", feature_names)
#     a.append(feature_names)
#     unigrams = [v for v in feature_names if len(v.split(' ')) == 1]

#     bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
#     print("# '{}':".format(Useful))
#     print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
#     print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
    
# print(a[0] == a[1])


# to_predict = ["I have outdated information on my credit report that I have previously disputed that has yet to be removed this information is more then seven years old and does not meet credit reporting requirements"]
# to_predict = ["Hi John, Have you sent Greg Enron Europe's 2001 Goals & Objectives (no more than 3 to 4 each)? If not, he needs them asap. I'll also check through his emails to see if you sent them already. Many Thanks, Liz Taylor"]
# to_predict = ["Hello, Everyone - This confirms the next meeting of the RTO West Regional Representatives Group (RRG) for Friday, November 9, at the Kingstad Meeting Center, Room F. The meeting will start at 8:30 a.m. and by 12:30 p.m. The Kingstad MeetingCenter is in the same building as the RTO West administrative office. Wewill meet in the same room we used for the PJM-LMP Congestion Managementbriefing with Seabron Adamson and Andrew Ott on October 23. Coffee,pastries, and jiuce will be served.The address of the Kingstad Center is 5933 NE Win Sivers Drive, and as mostof you know, it is located about three miles directly east of the Portlandairport. Go about three miles east on Airport Way and take a right on WinSivers Drive and right again at the second driveway. Parking will be available in Kingstad marked spaces as well as overflow parking in the Leatherman\'s lot across the street. If you have any questions about the logistics for the meeting, please call Judy Welch at (503) 262-9421. Early next week I\'ll send out an agenda for the meeting. Have a great weekend. - Bud\""]
# print('Predicted probabilities of demo input string are')
# print(calibrated_svc.predict_proba(p_tfidf))
